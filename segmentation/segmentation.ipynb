# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

import matplotlib.pyplot as plt

from detectron2.evaluation.coco_evaluation import COCOEvaluator

# %%
import torch, detectron2

TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# torch:  1.13 ; cuda:  cu117
# detectron2: 0.6

# %%
######################### Load Weights ############################

# %%
if not "resnet50-0676ba61.pth" in os.listdir():
    # !wget https://download.pytorch.org/models/resnet50-0676ba61.pth

# %%
if not "resnet50-0676ba61.pkl" in os.listdir():
    # !python ./detectron2/tools/convert-torchvision-to-d2.py \
        resnet50-0676ba61.pth \
        resnet50-0676ba61.pkl

# %%
# !python ./detectron2/tools/convert-torchvision-to-d2.py \
        tempo50_95_2.pth \
        tempo50_95_2.pkl
# Out:
# conv1.weight -> stem.conv1.weight
# bn1.weight -> stem.conv1.norm.weight
# bn1.bias -> stem.conv1.norm.bias
# bn1.running_mean -> stem.conv1.norm.running_mean
# bn1.running_var -> stem.conv1.norm.running_var
# bn1.num_batches_tracked -> stem.conv1.norm.num_batches_tracked
# layer1.0.conv1.weight -> res2.0.conv1.weight
# layer1.0.bn1.weight -> res2.0.conv1.norm.weight
# layer1.0.bn1.bias -> res2.0.conv1.norm.bias
# layer1.0.bn1.running_mean -> res2.0.conv1.norm.running_mean
# layer1.0.bn1.running_var -> res2.0.conv1.norm.running_var
# layer1.0.bn1.num_batches_tracked -> res2.0.conv1.norm.num_batches_tracked
# layer1.0.conv2.weight -> res2.0.conv2.weight
# layer1.0.bn2.weight -> res2.0.conv2.norm.weight
# layer1.0.bn2.bias -> res2.0.conv2.norm.bias
# layer1.0.bn2.running_mean -> res2.0.conv2.norm.running_mean
# layer1.0.bn2.running_var -> res2.0.conv2.norm.running_var
# layer1.0.bn2.num_batches_tracked -> res2.0.conv2.norm.num_batches_tracked
# layer1.0.conv3.weight -> res2.0.conv3.weight
# layer1.0.bn3.weight -> res2.0.conv3.norm.weight
# layer1.0.bn3.bias -> res2.0.conv3.norm.bias
# layer1.0.bn3.running_mean -> res2.0.conv3.norm.running_mean
# layer1.0.bn3.running_var -> res2.0.conv3.norm.running_var
# layer1.0.bn3.num_batches_tracked -> res2.0.conv3.norm.num_batches_tracked
# layer1.0.downsample.0.weight -> res2.0.shortcut.weight
# layer1.0.downsample.1.weight -> res2.0.shortcut.norm.weight
# layer1.0.downsample.1.bias -> res2.0.shortcut.norm.bias
# layer1.0.downsample.1.running_mean -> res2.0.shortcut.norm.running_mean
# layer1.0.downsample.1.running_var -> res2.0.shortcut.norm.running_var
# layer1.0.downsample.1.num_batches_tracked -> res2.0.shortcut.norm.num_batches_tracked
# layer1.1.conv1.weight -> res2.1.conv1.weight
# layer1.1.bn1.weight -> res2.1.conv1.norm.weight
# layer1.1.bn1.bias -> res2.1.conv1.norm.bias
# layer1.1.bn1.running_mean -> res2.1.conv1.norm.running_mean
# layer1.1.bn1.running_var -> res2.1.conv1.norm.running_var
# layer1.1.bn1.num_batches_tracked -> res2.1.conv1.norm.num_batches_tracked
# layer1.1.conv2.weight -> res2.1.conv2.weight
# layer1.1.bn2.weight -> res2.1.conv2.norm.weight
# layer1.1.bn2.bias -> res2.1.conv2.norm.bias
# layer1.1.bn2.running_mean -> res2.1.conv2.norm.running_mean
# layer1.1.bn2.running_var -> res2.1.conv2.norm.running_var
# layer1.1.bn2.num_batches_tracked -> res2.1.conv2.norm.num_batches_tracked
# layer1.1.conv3.weight -> res2.1.conv3.weight
# layer1.1.bn3.weight -> res2.1.conv3.norm.weight
# layer1.1.bn3.bias -> res2.1.conv3.norm.bias
# layer1.1.bn3.running_mean -> res2.1.conv3.norm.running_mean
# layer1.1.bn3.running_var -> res2.1.conv3.norm.running_var
# layer1.1.bn3.num_batches_tracked -> res2.1.conv3.norm.num_batches_tracked
# layer1.2.conv1.weight -> res2.2.conv1.weight
# layer1.2.bn1.weight -> res2.2.conv1.norm.weight
# layer1.2.bn1.bias -> res2.2.conv1.norm.bias
# layer1.2.bn1.running_mean -> res2.2.conv1.norm.running_mean
# layer1.2.bn1.running_var -> res2.2.conv1.norm.running_var
# layer1.2.bn1.num_batches_tracked -> res2.2.conv1.norm.num_batches_tracked
# layer1.2.conv2.weight -> res2.2.conv2.weight
# layer1.2.bn2.weight -> res2.2.conv2.norm.weight
# layer1.2.bn2.bias -> res2.2.conv2.norm.bias
# layer1.2.bn2.running_mean -> res2.2.conv2.norm.running_mean
# layer1.2.bn2.running_var -> res2.2.conv2.norm.running_var
# layer1.2.bn2.num_batches_tracked -> res2.2.conv2.norm.num_batches_tracked
# layer1.2.conv3.weight -> res2.2.conv3.weight
# layer1.2.bn3.weight -> res2.2.conv3.norm.weight
# layer1.2.bn3.bias -> res2.2.conv3.norm.bias
# layer1.2.bn3.running_mean -> res2.2.conv3.norm.running_mean
# layer1.2.bn3.running_var -> res2.2.conv3.norm.running_var
# layer1.2.bn3.num_batches_tracked -> res2.2.conv3.norm.num_batches_tracked
# layer2.0.conv1.weight -> res3.0.conv1.weight
# layer2.0.bn1.weight -> res3.0.conv1.norm.weight
# layer2.0.bn1.bias -> res3.0.conv1.norm.bias
# layer2.0.bn1.running_mean -> res3.0.conv1.norm.running_mean
# layer2.0.bn1.running_var -> res3.0.conv1.norm.running_var
# layer2.0.bn1.num_batches_tracked -> res3.0.conv1.norm.num_batches_tracked
# layer2.0.conv2.weight -> res3.0.conv2.weight
# layer2.0.bn2.weight -> res3.0.conv2.norm.weight
# layer2.0.bn2.bias -> res3.0.conv2.norm.bias
# layer2.0.bn2.running_mean -> res3.0.conv2.norm.running_mean
# layer2.0.bn2.running_var -> res3.0.conv2.norm.running_var
# layer2.0.bn2.num_batches_tracked -> res3.0.conv2.norm.num_batches_tracked
# layer2.0.conv3.weight -> res3.0.conv3.weight
# layer2.0.bn3.weight -> res3.0.conv3.norm.weight
# layer2.0.bn3.bias -> res3.0.conv3.norm.bias
# layer2.0.bn3.running_mean -> res3.0.conv3.norm.running_mean
# layer2.0.bn3.running_var -> res3.0.conv3.norm.running_var
# layer2.0.bn3.num_batches_tracked -> res3.0.conv3.norm.num_batches_tracked
# layer2.0.downsample.0.weight -> res3.0.shortcut.weight
# layer2.0.downsample.1.weight -> res3.0.shortcut.norm.weight
# layer2.0.downsample.1.bias -> res3.0.shortcut.norm.bias
# layer2.0.downsample.1.running_mean -> res3.0.shortcut.norm.running_mean
# layer2.0.downsample.1.running_var -> res3.0.shortcut.norm.running_var
# layer2.0.downsample.1.num_batches_tracked -> res3.0.shortcut.norm.num_batches_tracked
# layer2.1.conv1.weight -> res3.1.conv1.weight
# layer2.1.bn1.weight -> res3.1.conv1.norm.weight
# layer2.1.bn1.bias -> res3.1.conv1.norm.bias
# layer2.1.bn1.running_mean -> res3.1.conv1.norm.running_mean
# layer2.1.bn1.running_var -> res3.1.conv1.norm.running_var
# layer2.1.bn1.num_batches_tracked -> res3.1.conv1.norm.num_batches_tracked
# layer2.1.conv2.weight -> res3.1.conv2.weight
# layer2.1.bn2.weight -> res3.1.conv2.norm.weight
# layer2.1.bn2.bias -> res3.1.conv2.norm.bias
# layer2.1.bn2.running_mean -> res3.1.conv2.norm.running_mean
# layer2.1.bn2.running_var -> res3.1.conv2.norm.running_var
# layer2.1.bn2.num_batches_tracked -> res3.1.conv2.norm.num_batches_tracked
# layer2.1.conv3.weight -> res3.1.conv3.weight
# layer2.1.bn3.weight -> res3.1.conv3.norm.weight
# layer2.1.bn3.bias -> res3.1.conv3.norm.bias
# layer2.1.bn3.running_mean -> res3.1.conv3.norm.running_mean
# layer2.1.bn3.running_var -> res3.1.conv3.norm.running_var
# layer2.1.bn3.num_batches_tracked -> res3.1.conv3.norm.num_batches_tracked
# layer2.2.conv1.weight -> res3.2.conv1.weight
# layer2.2.bn1.weight -> res3.2.conv1.norm.weight
# layer2.2.bn1.bias -> res3.2.conv1.norm.bias
# layer2.2.bn1.running_mean -> res3.2.conv1.norm.running_mean
# layer2.2.bn1.running_var -> res3.2.conv1.norm.running_var
# layer2.2.bn1.num_batches_tracked -> res3.2.conv1.norm.num_batches_tracked
# layer2.2.conv2.weight -> res3.2.conv2.weight
# layer2.2.bn2.weight -> res3.2.conv2.norm.weight
# layer2.2.bn2.bias -> res3.2.conv2.norm.bias
# layer2.2.bn2.running_mean -> res3.2.conv2.norm.running_mean
# layer2.2.bn2.running_var -> res3.2.conv2.norm.running_var
# layer2.2.bn2.num_batches_tracked -> res3.2.conv2.norm.num_batches_tracked
# layer2.2.conv3.weight -> res3.2.conv3.weight
# layer2.2.bn3.weight -> res3.2.conv3.norm.weight
# layer2.2.bn3.bias -> res3.2.conv3.norm.bias
# layer2.2.bn3.running_mean -> res3.2.conv3.norm.running_mean
# layer2.2.bn3.running_var -> res3.2.conv3.norm.running_var
# layer2.2.bn3.num_batches_tracked -> res3.2.conv3.norm.num_batches_tracked
# layer2.3.conv1.weight -> res3.3.conv1.weight
# layer2.3.bn1.weight -> res3.3.conv1.norm.weight
# layer2.3.bn1.bias -> res3.3.conv1.norm.bias
# layer2.3.bn1.running_mean -> res3.3.conv1.norm.running_mean
# layer2.3.bn1.running_var -> res3.3.conv1.norm.running_var
# layer2.3.bn1.num_batches_tracked -> res3.3.conv1.norm.num_batches_tracked
# layer2.3.conv2.weight -> res3.3.conv2.weight
# layer2.3.bn2.weight -> res3.3.conv2.norm.weight
# layer2.3.bn2.bias -> res3.3.conv2.norm.bias
# layer2.3.bn2.running_mean -> res3.3.conv2.norm.running_mean
# layer2.3.bn2.running_var -> res3.3.conv2.norm.running_var
# layer2.3.bn2.num_batches_tracked -> res3.3.conv2.norm.num_batches_tracked
# layer2.3.conv3.weight -> res3.3.conv3.weight
# layer2.3.bn3.weight -> res3.3.conv3.norm.weight
# layer2.3.bn3.bias -> res3.3.conv3.norm.bias
# layer2.3.bn3.running_mean -> res3.3.conv3.norm.running_mean
# layer2.3.bn3.running_var -> res3.3.conv3.norm.running_var
# layer2.3.bn3.num_batches_tracked -> res3.3.conv3.norm.num_batches_tracked
# layer3.0.conv1.weight -> res4.0.conv1.weight
# layer3.0.bn1.weight -> res4.0.conv1.norm.weight
# layer3.0.bn1.bias -> res4.0.conv1.norm.bias
# layer3.0.bn1.running_mean -> res4.0.conv1.norm.running_mean
# layer3.0.bn1.running_var -> res4.0.conv1.norm.running_var
# layer3.0.bn1.num_batches_tracked -> res4.0.conv1.norm.num_batches_tracked
# layer3.0.conv2.weight -> res4.0.conv2.weight
# layer3.0.bn2.weight -> res4.0.conv2.norm.weight
# layer3.0.bn2.bias -> res4.0.conv2.norm.bias
# layer3.0.bn2.running_mean -> res4.0.conv2.norm.running_mean
# layer3.0.bn2.running_var -> res4.0.conv2.norm.running_var
# layer3.0.bn2.num_batches_tracked -> res4.0.conv2.norm.num_batches_tracked
# layer3.0.conv3.weight -> res4.0.conv3.weight
# layer3.0.bn3.weight -> res4.0.conv3.norm.weight
# layer3.0.bn3.bias -> res4.0.conv3.norm.bias
# layer3.0.bn3.running_mean -> res4.0.conv3.norm.running_mean
# layer3.0.bn3.running_var -> res4.0.conv3.norm.running_var
# layer3.0.bn3.num_batches_tracked -> res4.0.conv3.norm.num_batches_tracked
# layer3.0.downsample.0.weight -> res4.0.shortcut.weight
# layer3.0.downsample.1.weight -> res4.0.shortcut.norm.weight
# layer3.0.downsample.1.bias -> res4.0.shortcut.norm.bias
# layer3.0.downsample.1.running_mean -> res4.0.shortcut.norm.running_mean
# layer3.0.downsample.1.running_var -> res4.0.shortcut.norm.running_var
# layer3.0.downsample.1.num_batches_tracked -> res4.0.shortcut.norm.num_batches_tracked
# layer3.1.conv1.weight -> res4.1.conv1.weight
# layer3.1.bn1.weight -> res4.1.conv1.norm.weight
# layer3.1.bn1.bias -> res4.1.conv1.norm.bias
# layer3.1.bn1.running_mean -> res4.1.conv1.norm.running_mean
# layer3.1.bn1.running_var -> res4.1.conv1.norm.running_var
# layer3.1.bn1.num_batches_tracked -> res4.1.conv1.norm.num_batches_tracked
# layer3.1.conv2.weight -> res4.1.conv2.weight
# layer3.1.bn2.weight -> res4.1.conv2.norm.weight
# layer3.1.bn2.bias -> res4.1.conv2.norm.bias
# layer3.1.bn2.running_mean -> res4.1.conv2.norm.running_mean
# layer3.1.bn2.running_var -> res4.1.conv2.norm.running_var
# layer3.4.bn1.running_var -> res4.4.conv1.norm.running_var
# layer3.4.bn1.num_batches_tracked -> res4.4.conv1.norm.num_batches_tracked
# layer3.4.conv2.weight -> res4.4.conv2.weight
# layer3.4.bn2.weight -> res4.4.conv2.norm.weight
# layer3.4.bn2.bias -> res4.4.conv2.norm.bias
# layer3.4.bn2.running_mean -> res4.4.conv2.norm.running_mean
# layer3.4.bn2.running_var -> res4.4.conv2.norm.running_var
# layer3.4.bn2.num_batches_tracked -> res4.4.conv2.norm.num_batches_tracked
# layer3.4.conv3.weight -> res4.4.conv3.weight
# layer3.4.bn3.weight -> res4.4.conv3.norm.weight
# layer3.4.bn3.bias -> res4.4.conv3.norm.bias
# layer3.4.bn3.running_mean -> res4.4.conv3.norm.running_mean
# layer3.4.bn3.running_var -> res4.4.conv3.norm.running_var
# layer3.4.bn3.num_batches_tracked -> res4.4.conv3.norm.num_batches_tracked
# layer3.5.conv1.weight -> res4.5.conv1.weight
# layer3.5.bn1.weight -> res4.5.conv1.norm.weight
# layer3.5.bn1.bias -> res4.5.conv1.norm.bias
# layer3.5.bn1.running_mean -> res4.5.conv1.norm.running_mean
# layer3.5.bn1.running_var -> res4.5.conv1.norm.running_var
# layer3.5.bn1.num_batches_tracked -> res4.5.conv1.norm.num_batches_tracked
# layer3.5.conv2.weight -> res4.5.conv2.weight
# layer3.5.bn2.weight -> res4.5.conv2.norm.weight
# layer3.5.bn2.bias -> res4.5.conv2.norm.bias
# layer3.5.bn2.running_mean -> res4.5.conv2.norm.running_mean
# layer3.5.bn2.running_var -> res4.5.conv2.norm.running_var
# layer3.5.bn2.num_batches_tracked -> res4.5.conv2.norm.num_batches_tracked
# layer3.5.conv3.weight -> res4.5.conv3.weight
# layer3.5.bn3.weight -> res4.5.conv3.norm.weight
# layer3.5.bn3.bias -> res4.5.conv3.norm.bias
# layer3.5.bn3.running_mean -> res4.5.conv3.norm.running_mean
# layer3.5.bn3.running_var -> res4.5.conv3.norm.running_var
# layer3.5.bn3.num_batches_tracked -> res4.5.conv3.norm.num_batches_tracked
# layer4.0.conv1.weight -> res5.0.conv1.weight
# layer4.0.bn1.weight -> res5.0.conv1.norm.weight
# layer4.0.bn1.bias -> res5.0.conv1.norm.bias
# layer4.0.bn1.running_mean -> res5.0.conv1.norm.running_mean
# layer4.0.bn1.running_var -> res5.0.conv1.norm.running_var
# layer4.0.bn1.num_batches_tracked -> res5.0.conv1.norm.num_batches_tracked
# layer4.0.conv2.weight -> res5.0.conv2.weight
# layer4.0.bn2.weight -> res5.0.conv2.norm.weight
# layer4.0.bn2.bias -> res5.0.conv2.norm.bias
# layer4.0.bn2.running_mean -> res5.0.conv2.norm.running_mean
# layer4.0.bn2.running_var -> res5.0.conv2.norm.running_var
# layer4.0.bn2.num_batches_tracked -> res5.0.conv2.norm.num_batches_tracked
# layer4.0.conv3.weight -> res5.0.conv3.weight
# layer4.0.bn3.weight -> res5.0.conv3.norm.weight
# layer4.0.bn3.bias -> res5.0.conv3.norm.bias
# layer4.0.bn3.running_mean -> res5.0.conv3.norm.running_mean
# layer4.0.bn3.running_var -> res5.0.conv3.norm.running_var
# layer4.0.bn3.num_batches_tracked -> res5.0.conv3.norm.num_batches_tracked
# layer4.0.downsample.0.weight -> res5.0.shortcut.weight
# layer4.0.downsample.1.weight -> res5.0.shortcut.norm.weight
# layer4.0.downsample.1.bias -> res5.0.shortcut.norm.bias
# layer4.0.downsample.1.running_mean -> res5.0.shortcut.norm.running_mean
# layer4.0.downsample.1.running_var -> res5.0.shortcut.norm.running_var
# layer4.0.downsample.1.num_batches_tracked -> res5.0.shortcut.norm.num_batches_tracked
# layer4.1.conv1.weight -> res5.1.conv1.weight
# layer4.1.bn1.weight -> res5.1.conv1.norm.weight
# layer4.1.bn1.bias -> res5.1.conv1.norm.bias
# layer4.1.bn1.running_mean -> res5.1.conv1.norm.running_mean
# layer4.1.bn1.running_var -> res5.1.conv1.norm.running_var
# layer4.1.bn1.num_batches_tracked -> res5.1.conv1.norm.num_batches_tracked
# layer4.1.conv2.weight -> res5.1.conv2.weight
# layer4.1.bn2.weight -> res5.1.conv2.norm.weight
# layer4.1.bn2.bias -> res5.1.conv2.norm.bias
# layer4.1.bn2.running_mean -> res5.1.conv2.norm.running_mean
# layer4.1.bn2.running_var -> res5.1.conv2.norm.running_var
# layer4.1.bn2.num_batches_tracked -> res5.1.conv2.norm.num_batches_tracked
# layer4.1.conv3.weight -> res5.1.conv3.weight
# layer4.1.bn3.weight -> res5.1.conv3.norm.weight
# layer4.1.bn3.bias -> res5.1.conv3.norm.bias
# layer4.1.bn3.running_mean -> res5.1.conv3.norm.running_mean
# layer4.1.bn3.running_var -> res5.1.conv3.norm.running_var
# layer4.1.bn3.num_batches_tracked -> res5.1.conv3.norm.num_batches_tracked
# layer4.2.conv1.weight -> res5.2.conv1.weight
# layer4.2.bn1.weight -> res5.2.conv1.norm.weight
# layer4.2.bn1.bias -> res5.2.conv1.norm.bias
# layer4.2.bn1.running_mean -> res5.2.conv1.norm.running_mean
# layer4.2.bn1.running_var -> res5.2.conv1.norm.running_var
# layer4.2.bn1.num_batches_tracked -> res5.2.conv1.norm.num_batches_tracked
# layer4.2.conv2.weight -> res5.2.conv2.weight
# layer4.2.bn2.weight -> res5.2.conv2.norm.weight
# layer4.2.bn2.bias -> res5.2.conv2.norm.bias
# layer4.2.bn2.running_mean -> res5.2.conv2.norm.running_mean
# layer4.2.bn2.running_var -> res5.2.conv2.norm.running_var
# layer4.2.bn2.num_batches_tracked -> res5.2.conv2.norm.num_batches_tracked
# layer4.2.conv3.weight -> res5.2.conv3.weight
# layer4.2.bn3.weight -> res5.2.conv3.norm.weight
# layer4.2.bn3.bias -> res5.2.conv3.norm.bias
# layer4.2.bn3.running_mean -> res5.2.conv3.norm.running_mean
# layer4.2.bn3.running_var -> res5.2.conv3.norm.running_var
# layer4.2.bn3.num_batches_tracked -> res5.2.conv3.norm.num_batches_tracked
# fc.weight -> stem.fc.weight
# fc.bias -> stem.fc.bias

# %%
###################################################################

# %%
# if your dataset is in COCO format, this cell can be replaced by the following three lines:
from detectron2.data.datasets import register_coco_instances
register_coco_instances("asl_train", {}, "../datasets/ASL_mask/annotations/instances_Train.json", "../datasets/ASL_mask/images")
register_coco_instances("asl_val", {}, "../datasets/ASL_mask/annotations/instances_Test.json", "../datasets/ASL_mask/images")

# %%
asl_metadata = MetadataCatalog.get("asl_train")
dataset_dicts = DatasetCatalog.get("asl_train")
# Out:
# [05/31 16:50:59 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Train.json

# %%
for d in random.sample(dataset_dicts, 10):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=asl_metadata, scale=0.5)
    out = visualizer.draw_dataset_dict(d)
    cv2.imshow("", out.get_image()[:, :, ::-1])
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)
#
# QObject::moveToThread: Current thread (0x6496be0) is not the object's thread (0x6b8ffa0).
# Cannot move to target thread (0x6496be0)

# %%
from detectron2.engine import DefaultTrainer

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

cfg.INPUT.MASK_FORMAT='bitmask'

cfg.DATASETS.TRAIN = ("asl_train",)
cfg.DATASETS.TEST = ("asl_val",)
cfg.TEST.EVAL_PERIOD = 1_000

cfg.DATALOADER.NUM_WORKERS = 2
# cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
# cfg.MODEL.WEIGHTS = "resnet50-0676ba61.pkl"
# cfg.MODEL.WEIGHTS = "tempo50_95.pkl"
cfg.MODEL.WEIGHTS = "baseline50.pkl"

cfg.OUTPUT_DIR = "./output_baseline_final/5"
cfg.SOLVER.CHECKPOINT_PERIOD = 1_000

cfg.MODEL.PIXEL_MEAN = [123.675, 116.280, 103.530]
cfg.MODEL.PIXEL_STD = [58.395, 57.120, 57.375]
cfg.MODEL.RESNETS.DEPTH = 50
cfg.MODEL.RESNETS.STRIDE_IN_1X1 = False
cfg.INPUT.FORMAT = "RGB"

cfg.SOLVER.IMS_PER_BATCH = 5  # This is the real "batch size" commonly known to deep learning people
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 15_000    # 300 iterations seems good enough for this toy dataset; you will need to train longer for a practical dataset
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512   # The "RoIHead batch size". 128 is faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 24  # only has one class (ballon). (see https://detectron2.readthedocs.io/tutorials/datasets.html#update-the-config-for-new-datasets)
# NOTE: this config means the number of classes, but a few popular unofficial tutorials incorrect uses num_classes+1 here.

# %%
cfg.DATASETS
# Out:
# CfgNode({'TRAIN': ('asl_train',), 'PROPOSAL_FILES_TRAIN': (), 'PRECOMPUTED_PROPOSAL_TOPK_TRAIN': 2000, 'TEST': ('asl_val',), 'PROPOSAL_FILES_TEST': (), 'PRECOMPUTED_PROPOSAL_TOPK_TEST': 1000})

# %%
class Trainer(DefaultTrainer):
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        return COCOEvaluator("asl_val",)

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [05/31 16:51:10 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=25, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=96, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [05/31 16:51:10 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Train.json
# [05/31 16:51:10 d2.data.build]: Removed 0 images with no usable annotations. 120 images left.
# [05/31 16:51:10 d2.data.build]: Distribution of instances among all 24 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |     A      | 5            |     B      | 5            |     C      | 5            |
# |     D      | 5            |     E      | 5            |     F      | 5            |
# |     G      | 5            |     H      | 5            |     I      | 5            |
# |     K      | 5            |     L      | 5            |     M      | 5            |
# |     N      | 5            |     O      | 5            |     P      | 5            |
# |     Q      | 5            |     R      | 5            |     S      | 5            |
# |     T      | 5            |     U      | 5            |     V      | 5            |
# |     W      | 5            |     X      | 5            |     Y      | 5            |
# |            |              |            |              |            |              |
# |   total    | 120          |            |              |            |              |
# [05/31 16:51:10 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [05/31 16:51:10 d2.data.build]: Using training sampler TrainingSampler
# [05/31 16:51:10 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/31 16:51:10 d2.data.common]: Serializing 120 elements to byte tensors and concatenating them all ...
# [05/31 16:51:10 d2.data.common]: Serialized dataset takes 0.08 MiB
# [05/31 16:51:10 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from baseline50.pkl ...
# [05/31 16:51:10 d2.checkpoint.c2_model_loading]: Following weights matched with submodule backbone.bottom_up:
# | Names in Model    | Names in Checkpoint                                                               | Shapes                                          |
# |:------------------|:----------------------------------------------------------------------------------|:------------------------------------------------|
# | res2.0.conv1.*    | res2.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,1,1)             |
# | res2.0.conv2.*    | res2.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | res2.0.conv3.*    | res2.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.0.shortcut.* | res2.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.1.conv1.*    | res2.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,256,1,1)            |
# | res2.1.conv2.*    | res2.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | res2.1.conv3.*    | res2.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res2.2.conv1.*    | res2.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,256,1,1)            |
# | res2.2.conv2.*    | res2.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (64,) (64,) (64,) (64,) (64,64,3,3)             |
# | res2.2.conv3.*    | res2.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,64,1,1)        |
# | res3.0.conv1.*    | res3.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,256,1,1)       |
# | res3.0.conv2.*    | res3.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | res3.0.conv3.*    | res3.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | res3.0.shortcut.* | res3.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (512,) (512,) (512,) (512,) (512,256,1,1)       |
# | res3.1.conv1.*    | res3.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | res3.1.conv2.*    | res3.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | res3.1.conv3.*    | res3.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | res3.2.conv1.*    | res3.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | res3.2.conv2.*    | res3.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | res3.2.conv3.*    | res3.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | res3.3.conv1.*    | res3.3.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,512,1,1)       |
# | res3.3.conv2.*    | res3.3.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (128,) (128,) (128,) (128,) (128,128,3,3)       |
# | res3.3.conv3.*    | res3.3.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,128,1,1)       |
# | res4.0.conv1.*    | res4.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,512,1,1)       |
# | res4.0.conv2.*    | res4.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.0.conv3.*    | res4.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res4.0.shortcut.* | res4.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (1024,) (1024,) (1024,) (1024,) (1024,512,1,1)  |
# | res4.1.conv1.*    | res4.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | res4.1.conv2.*    | res4.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.1.conv3.*    | res4.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res4.2.conv1.*    | res4.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | res4.2.conv2.*    | res4.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.2.conv3.*    | res4.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res4.3.conv1.*    | res4.3.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | res4.3.conv2.*    | res4.3.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.3.conv3.*    | res4.3.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res4.4.conv1.*    | res4.4.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | res4.4.conv2.*    | res4.4.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.4.conv3.*    | res4.4.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res4.5.conv1.*    | res4.5.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,1024,1,1)      |
# | res4.5.conv2.*    | res4.5.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (256,) (256,) (256,) (256,) (256,256,3,3)       |
# | res4.5.conv3.*    | res4.5.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (1024,) (1024,) (1024,) (1024,) (1024,256,1,1)  |
# | res5.0.conv1.*    | res5.0.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,1024,1,1)      |
# | res5.0.conv2.*    | res5.0.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | res5.0.conv3.*    | res5.0.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | res5.0.shortcut.* | res5.0.shortcut.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight} | (2048,) (2048,) (2048,) (2048,) (2048,1024,1,1) |
# | res5.1.conv1.*    | res5.1.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,2048,1,1)      |
# | res5.1.conv2.*    | res5.1.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | res5.1.conv3.*    | res5.1.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | res5.2.conv1.*    | res5.2.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,2048,1,1)      |
# | res5.2.conv2.*    | res5.2.conv2.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (512,) (512,) (512,) (512,) (512,512,3,3)       |
# | res5.2.conv3.*    | res5.2.conv3.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}    | (2048,) (2048,) (2048,) (2048,) (2048,512,1,1)  |
# | stem.conv1.*      | stem.conv1.{norm.bias,norm.running_mean,norm.running_var,norm.weight,weight}      | (64,) (64,) (64,) (64,) (64,3,7,7)              |
# Some model parameters or buffers are not found in the checkpoint:
# backbone.fpn_lateral2.{bias, weight}
# backbone.fpn_lateral3.{bias, weight}
# backbone.fpn_lateral4.{bias, weight}
# backbone.fpn_lateral5.{bias, weight}
# backbone.fpn_output2.{bias, weight}
# backbone.fpn_output3.{bias, weight}
# backbone.fpn_output4.{bias, weight}
# backbone.fpn_output5.{bias, weight}
# proposal_generator.rpn_head.anchor_deltas.{bias, weight}
# proposal_generator.rpn_head.conv.{bias, weight}
# proposal_generator.rpn_head.objectness_logits.{bias, weight}
# roi_heads.box_head.fc1.{bias, weight}
# roi_heads.box_head.fc2.{bias, weight}
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.deconv.{bias, weight}
# roi_heads.mask_head.mask_fcn1.{bias, weight}
# roi_heads.mask_head.mask_fcn2.{bias, weight}
# roi_heads.mask_head.mask_fcn3.{bias, weight}
# roi_heads.mask_head.mask_fcn4.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# The checkpoint state_dict contains keys that are not used by the model:
#   res2.0.conv1.norm.num_batches_tracked
#   res2.0.conv2.norm.num_batches_tracked
#   res2.0.conv3.norm.num_batches_tracked
#   res2.0.shortcut.norm.num_batches_tracked
#   res2.1.conv1.norm.num_batches_tracked
#   res2.1.conv2.norm.num_batches_tracked
#   res2.1.conv3.norm.num_batches_tracked
#   res2.2.conv1.norm.num_batches_tracked
#   res2.2.conv2.norm.num_batches_tracked
#   res2.2.conv3.norm.num_batches_tracked
#   res3.0.conv1.norm.num_batches_tracked
#   res3.0.conv2.norm.num_batches_tracked
#   res3.0.conv3.norm.num_batches_tracked
#   res3.0.shortcut.norm.num_batches_tracked
#   res3.1.conv1.norm.num_batches_tracked
#   res3.1.conv2.norm.num_batches_tracked
#   res3.1.conv3.norm.num_batches_tracked
#   res3.2.conv1.norm.num_batches_tracked
#   res3.2.conv2.norm.num_batches_tracked
#   res3.2.conv3.norm.num_batches_tracked
#   res3.3.conv1.norm.num_batches_tracked
#   res3.3.conv2.norm.num_batches_tracked
#   res3.3.conv3.norm.num_batches_tracked
#   res4.0.conv1.norm.num_batches_tracked
#   res4.0.conv2.norm.num_batches_tracked
#   res4.0.conv3.norm.num_batches_tracked
#   res4.0.shortcut.norm.num_batches_tracked
#   res4.1.conv1.norm.num_batches_tracked
#   res4.1.conv2.norm.num_batches_tracked
#   res4.1.conv3.norm.num_batches_tracked
#   res4.2.conv1.norm.num_batches_tracked
#   res4.2.conv2.norm.num_batches_tracked
#   res4.2.conv3.norm.num_batches_tracked
#   res4.3.conv1.norm.num_batches_tracked
#   res4.3.conv2.norm.num_batches_tracked
#   res4.3.conv3.norm.num_batches_tracked
#   res4.4.conv1.norm.num_batches_tracked
#   res4.4.conv2.norm.num_batches_tracked
#   res4.4.conv3.norm.num_batches_tracked
#   res4.5.conv1.norm.num_batches_tracked
#   res4.5.conv2.norm.num_batches_tracked
#   res4.5.conv3.norm.num_batches_tracked
#   res5.0.conv1.norm.num_batches_tracked
#   res5.0.conv2.norm.num_batches_tracked
#   res5.0.conv3.norm.num_batches_tracked
#   res5.0.shortcut.norm.num_batches_tracked
#   res5.1.conv1.norm.num_batches_tracked
#   res5.1.conv2.norm.num_batches_tracked
#   res5.1.conv3.norm.num_batches_tracked
#   res5.2.conv1.norm.num_batches_tracked
#   res5.2.conv2.norm.num_batches_tracked
#   res5.2.conv3.norm.num_batches_tracked
#   stem.conv1.norm.num_batches_tracked
#   stem.fc.{bias, weight}
# [05/31 16:51:10 d2.engine.train_loop]: Starting training from iteration 0
# /home/yasin/anaconda3/lib/python3.9/site-packages/detectron2/data/detection_utils.py:446: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   torch.stack([torch.from_numpy(np.ascontiguousarray(x)) for x in masks])
# /home/yasin/anaconda3/lib/python3.9/site-packages/detectron2/data/detection_utils.py:446: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   torch.stack([torch.from_numpy(np.ascontiguousarray(x)) for x in masks])
# /home/yasin/anaconda3/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [05/31 16:51:23 d2.utils.events]:  eta: 2:25:01  iter: 19  total_loss: 4.646  loss_cls: 3.249  loss_box_reg: 4.056e-05  loss_mask: 0.6931  loss_rpn_cls: 0.6961  loss_rpn_loc: 0.006805    time: 0.5717  last_time: 0.5776  data_time: 0.0243  last_data_time: 0.0176   lr: 4.9953e-06  max_mem: 4413M
# [05/31 16:51:34 d2.utils.events]:  eta: 2:24:41  iter: 39  total_loss: 4.541  loss_cls: 3.139  loss_box_reg: 4.759e-05  loss_mask: 0.6932  loss_rpn_cls: 0.6954  loss_rpn_loc: 0.007729    time: 0.5593  last_time: 0.5830  data_time: 0.0197  last_data_time: 0.0210   lr: 9.9902e-06  max_mem: 4413M
# [05/31 16:51:45 d2.utils.events]:  eta: 2:24:32  iter: 59  total_loss: 4.262  loss_cls: 2.866  loss_box_reg: 0.001561  loss_mask: 0.6932  loss_rpn_cls: 0.6937  loss_rpn_loc: 0.007273    time: 0.5596  last_time: 0.5861  data_time: 0.0201  last_data_time: 0.0188   lr: 1.4985e-05  max_mem: 4413M
# [05/31 16:51:56 d2.utils.events]:  eta: 2:24:38  iter: 79  total_loss: 3.608  loss_cls: 2.216  loss_box_reg: 5.763e-05  loss_mask: 0.6931  loss_rpn_cls: 0.6904  loss_rpn_loc: 0.006051    time: 0.5610  last_time: 0.5876  data_time: 0.0202  last_data_time: 0.0196   lr: 1.998e-05  max_mem: 4485M
# [05/31 17:00:59 d2.utils.events]:  eta: 2:23:53  iter: 959  total_loss: 0.3792  loss_cls: 0.09557  loss_box_reg: 0.08049  loss_mask: 0.159  loss_rpn_cls: 0.005144  loss_rpn_loc: 0.01127    time: 0.6113  last_time: 0.6111  data_time: 0.0208  last_data_time: 0.0208   lr: 0.00023976  max_mem: 4809M
# [05/31 17:01:11 d2.utils.events]:  eta: 2:23:41  iter: 979  total_loss: 0.3466  loss_cls: 0.09284  loss_box_reg: 0.07475  loss_mask: 0.1486  loss_rpn_cls: 0.005961  loss_rpn_loc: 0.01243    time: 0.6116  last_time: 0.6068  data_time: 0.0200  last_data_time: 0.0196   lr: 0.00024476  max_mem: 4809M
# [05/31 17:01:24 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Test.json
# [05/31 17:01:24 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [05/31 17:01:24 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/31 17:01:24 d2.data.common]: Serializing 120 elements to byte tensors and concatenating them all ...
# [05/31 17:01:24 d2.data.common]: Serialized dataset takes 0.08 MiB
# [05/31 17:01:24 d2.evaluation.evaluator]: Start inference on 120 batches
# [05/31 17:01:25 d2.evaluation.evaluator]: Inference done 11/120. Dataloading: 0.0006 s/iter. Inference: 0.0542 s/iter. Eval: 0.0017 s/iter. Total: 0.0565 s/iter. ETA=0:00:06
# [05/31 17:01:30 d2.evaluation.evaluator]: Inference done 99/120. Dataloading: 0.0007 s/iter. Inference: 0.0542 s/iter. Eval: 0.0018 s/iter. Total: 0.0568 s/iter. ETA=0:00:01
# [05/31 17:01:31 d2.evaluation.evaluator]: Total inference time: 0:00:06.560390 (0.057047 s / iter per device, on 1 devices)
# [05/31 17:01:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:06 (0.054172 s / iter per device, on 1 devices)
# [05/31 17:01:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [05/31 17:01:31 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [05/31 17:01:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [05/31 17:01:31 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.13 seconds.
# [05/31 17:01:31 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/31 17:01:31 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.607
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.533
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.688
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.541
# [05/31 17:01:31 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 22.212 | 40.485 | 19.012 |  nan  | 60.687 | 22.114 |
# [05/31 17:01:31 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [05/31 17:01:31 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | A          | 21.250 | B          | 31.827 | C          | 18.399 |
# | D          | 14.824 | E          | 3.442  | F          | 43.328 |
# | G          | 28.651 | H          | 13.877 | I          | 8.113  |
# | K          | 10.651 | L          | 26.074 | M          | 3.736  |
# | N          | 21.077 | O          | 51.650 | P          | 63.218 |
# | Q          | 28.638 | R          | 9.786  | S          | 4.292  |
# | T          | 22.525 | U          | 15.978 | V          | 7.769  |
# | W          | 14.815 | X          | 19.103 | Y          | 50.066 |
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# [05/31 17:01:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [05/31 17:01:32 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.05 seconds.
# [05/31 17:01:32 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 423, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 650, in _save
#     zip_file.write_record(name, storage.data_ptr(), num_bytes)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/detectron2/engine/train_loop.py", line 156, in train
#     self.after_step()
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/detectron2/engine/train_loop.py", line 190, in after_step
#     h.after_step()
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/detectron2/engine/hooks.py", line 207, in after_step
#     self.step(self.trainer.iter)
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/fvcore/common/checkpoint.py", line 430, in step
#     self.checkpointer.save(
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/fvcore/common/checkpoint.py", line 126, in save
#     torch.save(data, f)
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 424, in save
#     return
#   File "/home/yasin/anaconda3/lib/python3.9/site-packages/torch/serialization.py", line 299, in __exit__
#     self.file_like.write_end_of_file()
# RuntimeError: [enforce fail at inline_container.cc:325] . unexpected pos 96376256 vs 96376144
# [05/31 19:32:07 d2.engine.hooks]: Overall training speed: 14997 iterations in 2:39:00 (0.6362 s / it)
# [05/31 19:32:07 d2.engine.hooks]: Total training time: 2:40:54 (0:01:53 on hooks)
# [05/31 19:32:07 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Test.json
# [05/31 19:32:07 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [05/31 19:32:07 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/31 19:32:07 d2.data.common]: Serializing 120 elements to byte tensors and concatenating them all ...
# [05/31 19:32:07 d2.data.common]: Serialized dataset takes 0.08 MiB
# [05/31 19:32:07 d2.evaluation.evaluator]: Start inference on 120 batches
# [05/31 19:32:07 d2.evaluation.evaluator]: Inference done 11/120. Dataloading: 0.0006 s/iter. Inference: 0.0528 s/iter. Eval: 0.0008 s/iter. Total: 0.0542 s/iter. ETA=0:00:05
# [05/31 19:32:12 d2.evaluation.evaluator]: Inference done 103/120. Dataloading: 0.0008 s/iter. Inference: 0.0530 s/iter. Eval: 0.0009 s/iter. Total: 0.0547 s/iter. ETA=0:00:00
# [05/31 19:32:13 d2.evaluation.evaluator]: Total inference time: 0:00:06.337230 (0.055106 s / iter per device, on 1 devices)
# [05/31 19:32:13 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:06 (0.053041 s / iter per device, on 1 devices)
# [05/31 19:32:13 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [05/31 19:32:13 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [05/31 19:32:13 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.11 seconds.
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.703
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.742
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.696
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 57.332 | 85.126 | 67.042 |  nan  | 74.167 | 54.966 |
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | A          | 74.917 | B          | 58.119 | C          | 67.459 |
# | D          | 38.993 | E          | 60.078 | F          | 66.089 |
# | G          | 55.495 | H          | 49.431 | I          | 64.929 |
# | K          | 73.589 | L          | 70.198 | M          | 24.453 |
# | N          | 73.366 | O          | 71.279 | P          | 69.480 |
# | Q          | 53.248 | R          | 59.292 | S          | 19.403 |
# | T          | 65.149 | U          | 39.901 | V          | 65.672 |
# | W          | 41.056 | X          | 76.403 | Y          | 37.975 |
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.03 seconds.
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/31 19:32:14 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.697
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.827
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.804
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.692
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.840
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.848
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.848
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.842
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.843
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 69.656 | 85.126 | 82.698 |  nan  | 80.417 | 69.184 |
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [05/31 19:32:14 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | A          | 77.063 | B          | 87.248 | C          | 74.059 |
# | D          | 56.424 | E          | 67.956 | F          | 80.050 |
# | G          | 76.584 | H          | 53.366 | I          | 71.488 |
# | K          | 81.624 | L          | 80.594 | M          | 32.159 |
# | N          | 85.842 | O          | 80.899 | P          | 81.089 |
# | Q          | 71.624 | R          | 62.993 | S          | 27.325 |
# | T          | 87.624 | U          | 56.172 | V          | 73.663 |
# | W          | 56.997 | X          | 86.073 | Y          | 62.830 |
# [05/31 19:32:14 d2.engine.defaults]: Evaluation results for asl_val in csv format:
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: Task: bbox
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: 57.3322,85.1265,67.0418,nan,74.1667,54.9665
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: Task: segm
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [05/31 19:32:14 d2.evaluation.testing]: copypaste: 69.6560,85.1265,82.6984,nan,80.4167,69.1841
# [05/31 19:32:14 d2.utils.events]:  eta: 0:00:00  iter: 14999  total_loss: 0.06722  loss_cls: 0.01132  loss_box_reg: 0.02631  loss_mask: 0.02756  loss_rpn_cls: 0.0003623  loss_rpn_loc: 0.001666    time: 0.6361  last_time: 0.6732  data_time: 0.0206  last_data_time: 0.0200   lr: 0.00025  max_mem: 4982M
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     422         with _open_zipfile_writer(f) as opened_zipfile:
# --> 423             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424             return
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     649         num_bytes = storage.nbytes()
# --> 650         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     651
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_42674/1377931064.py in <module>
#       2 trainer = Trainer(cfg)
#       3 trainer.resume_or_load(resume=False)
# ----> 4 trainer.train()
#
# ~/anaconda3/lib/python3.9/site-packages/detectron2/engine/defaults.py in train(self)
#     482             OrderedDict of results, if evaluation is enabled. Otherwise None.
#     483         """
# --> 484         super().train(self.start_iter, self.max_iter)
#     485         if len(self.cfg.TEST.EXPECTED_RESULTS) and comm.is_main_process():
#     486             assert hasattr(
#
# ~/anaconda3/lib/python3.9/site-packages/detectron2/engine/train_loop.py in train(self, start_iter, max_iter)
#     154                     self.before_step()
#     155                     self.run_step()
# --> 156                     self.after_step()
#     157                 # self.iter == max_iter can be used by `after_train` to
#     158                 # tell whether the training successfully finished or failed
#
# ~/anaconda3/lib/python3.9/site-packages/detectron2/engine/train_loop.py in after_step(self)
#     188     def after_step(self):
#     189         for h in self._hooks:
# --> 190             h.after_step()
#     191
#     192     def run_step(self):
#
# ~/anaconda3/lib/python3.9/site-packages/detectron2/engine/hooks.py in after_step(self)
#     205     def after_step(self):
#     206         # No way to use **kwargs
# --> 207         self.step(self.trainer.iter)
#     208
#     209
#
# ~/anaconda3/lib/python3.9/site-packages/fvcore/common/checkpoint.py in step(self, iteration, **kwargs)
#     428
#     429         if (iteration + 1) % self.period == 0:
# --> 430             self.checkpointer.save(
#     431                 "{}_{:07d}".format(self.file_prefix, iteration), **additional_state
#     432             )
#
# ~/anaconda3/lib/python3.9/site-packages/fvcore/common/checkpoint.py in save(self, name, **kwargs)
#     124         self.logger.info("Saving checkpoint to {}".format(save_file))
#     125         with self.path_manager.open(save_file, "wb") as f:
# --> 126             torch.save(data, f)
#     127         self.tag_last_checkpoint(basename)
#     128
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     422         with _open_zipfile_writer(f) as opened_zipfile:
#     423             _save(obj, opened_zipfile, pickle_module, pickle_protocol)
# --> 424             return
#     425     else:
#     426         with _open_file_like(f, 'wb') as opened_file:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/serialization.py in __exit__(self, *args)
#     297
#     298     def __exit__(self, *args) -> None:
# --> 299         self.file_like.write_end_of_file()
#     300         self.buffer.flush()
#     301
#
# RuntimeError: [enforce fail at inline_container.cc:325] . unexpected pos 96376256 vs 96376144

# %%
# Inference should use the config with parameters that are used in training
# cfg now already contains everything we've set previously. We changed it a little bit for inference:
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set a custom testing threshold
predictor = DefaultPredictor(cfg)
# Out:
# [05/31 14:35:04 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output_baseline_final/4/model_final.pth ...

# %%
asl_metadata_test = MetadataCatalog.get("asl_val")
dataset_dicts_test = DatasetCatalog.get("asl_val")
# Out:
# [05/31 14:35:04 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Test.json

# %%
from detectron2.utils.visualizer import ColorMode

for d in random.sample(dataset_dicts_test, 20):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)  # format is documented at https://detectron2.readthedocs.io/tutorials/models.html#model-output-format
    v = Visualizer(im[:, :, ::-1],
                   metadata=asl_metadata_test, 
                   scale=0.5, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels. This option is only available for segmentation models
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2.imshow("", out.get_image()[:, :, ::-1])
    cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)
#
# QObject::moveToThread: Current thread (0x7aff9d0) is not the object's thread (0x7f2fe00).
# Cannot move to target thread (0x7aff9d0)

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("asl_val", output_dir="./output")
val_loader = build_detection_test_loader(cfg, "asl_val")
print(inference_on_dataset(predictor.model, val_loader, evaluator))
# another equivalent way to evaluate the model is to use `trainer.test`
# Out:
# [05/31 16:49:14 d2.data.datasets.coco]: Loaded 120 images in COCO format from ../datasets/ASL_mask/annotations/instances_Test.json
# [05/31 16:49:14 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [05/31 16:49:14 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [05/31 16:49:14 d2.data.common]: Serializing 120 elements to byte tensors and concatenating them all ...
# [05/31 16:49:14 d2.data.common]: Serialized dataset takes 0.08 MiB
# [05/31 16:49:14 d2.evaluation.evaluator]: Start inference on 120 batches
# [05/31 16:49:15 d2.evaluation.evaluator]: Inference done 11/120. Dataloading: 0.0006 s/iter. Inference: 0.0507 s/iter. Eval: 0.0003 s/iter. Total: 0.0516 s/iter. ETA=0:00:05
# [05/31 16:49:20 d2.evaluation.evaluator]: Inference done 107/120. Dataloading: 0.0008 s/iter. Inference: 0.0512 s/iter. Eval: 0.0003 s/iter. Total: 0.0523 s/iter. ETA=0:00:00
# [05/31 16:49:21 d2.evaluation.evaluator]: Total inference time: 0:00:06.071437 (0.052795 s / iter per device, on 1 devices)
# [05/31 16:49:21 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:05 (0.051446 s / iter per device, on 1 devices)
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.04 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.616
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.450
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.388
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.438
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 40.173 | 61.648 | 48.113 |  nan  | 45.008 | 38.847 |
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | A          | 68.608 | B          | 43.911 | C          | 48.218 |
# | D          | 12.475 | E          | 2.079  | F          | 73.168 |
# | G          | 54.208 | H          | 34.818 | I          | 45.677 |
# | K          | 48.119 | L          | 39.158 | M          | 10.396 |
# | N          | 67.587 | O          | 37.277 | P          | 57.228 |
# | Q          | 58.389 | R          | 0.000  | S          | 16.634 |
# | T          | 69.307 | U          | 64.392 | V          | 0.000  |
# | W          | 47.690 | X          | 64.818 | Y          | 0.000  |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.02 seconds.
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [05/31 16:49:21 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.03 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.616
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.528
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 49.050 | 61.648 | 56.869 |  nan  | 50.905 | 48.721 |
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [05/31 16:49:21 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP     | category   | AP     | category   | AP     |
# |:-----------|:-------|:-----------|:-------|:-----------|:-------|
# | A          | 77.208 | B          | 53.960 | C          | 64.851 |
# | D          | 18.713 | E          | 2.673  | F          | 80.099 |
# | G          | 71.188 | H          | 37.525 | I          | 52.409 |
# | K          | 64.495 | L          | 60.668 | M          | 16.634 |
# | N          | 73.427 | O          | 46.023 | P          | 68.688 |
# | Q          | 79.835 | R          | 0.000  | S          | 18.713 |
# | T          | 87.228 | U          | 75.743 | V          | 0.000  |
# | W          | 47.690 | X          | 79.439 | Y          | 0.000  |
# OrderedDict([('bbox', {'AP': 40.17326153402886, 'AP50': 61.647817712174145, 'AP75': 48.11265650374561, 'APs': nan, 'APm': 45.008250825082506, 'APl': 38.84697011367804, 'AP-A': 68.60836083608362, 'AP-B': 43.91089108910891, 'AP-C': 48.21782178217822, 'AP-D': 12.475247524752476, 'AP-E': 2.0792079207920793, 'AP-F': 73.16831683168317, 'AP-G': 54.207920792079214, 'AP-H': 34.81848184818482, 'AP-I': 45.67656765676568, 'AP-K': 48.11881188118812, 'AP-L': 39.15841584158416, 'AP-M': 10.396039603960396, 'AP-N': 67.58676966597758, 'AP-O': 37.277227722772274, 'AP-P': 57.227722772277225, 'AP-Q': 58.38943894389439, 'AP-R': 0.0, 'AP-S': 16.633663366336634, 'AP-T': 69.3069306930693, 'AP-U': 64.39218921892189, 'AP-V': 0.0, 'AP-W': 47.68976897689769, 'AP-X': 64.81848184818483, 'AP-Y': 0.0}), ('segm', {'AP': 49.05038619704461, 'AP50': 61.647817712174145, 'AP75': 56.86921485188813, 'APs': nan, 'APm': 50.9048404840484, 'APl': 48.72066045890303, 'AP-A': 77.20847084708471, 'AP-B': 53.960396039603964, 'AP-C': 64.85148514851485, 'AP-D': 18.712871287128714, 'AP-E': 2.6732673267326734, 'AP-F': 80.0990099009901, 'AP-G': 71.18811881188118, 'AP-H': 37.524752475247524, 'AP-I': 52.409240924092416, 'AP-K': 64.4950495049505, 'AP-L': 60.668316831683164, 'AP-M': 16.633663366336634, 'AP-N': 73.42654045624343, 'AP-O': 46.02310231023103, 'AP-P': 68.6881188118812, 'AP-Q': 79.83498349834983, 'AP-R': 0.0, 'AP-S': 18.712871287128714, 'AP-T': 87.22772277227723, 'AP-U': 75.74257425742574, 'AP-V': 0.0, 'AP-W': 47.68976897689769, 'AP-X': 79.43894389438945, 'AP-Y': 0.0})])
